# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh141099/All_Training_Assignments/blob/main/sep_12__Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('/content/Placement_Data_Full_Class.csv')

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
sns.heatmap(data.isnull(),cmap = 'viridis',cbar = False)

# %% [markdown]
# Frequency distribution

# %% [markdown]
# 1. gender

# %%
tab1 = pd.crosstab(index = data['gender'],columns = 'Freq')
tab1['Percentage'] = tab1['Freq']/tab1['Freq'].sum()*100

# %%
tab1
# Out:
# col_0   Freq  Percentage
# gender
# F         48   32.432432
# M        100   67.567568

# %% [markdown]
# 2. ssc_p

# %%
tab2  = pd.crosstab(index = data['ssc_p'],columns = 'Freq')
# Out:
# col_0  Freq
# ssc_p
# 49.00     1
# 52.60     1
# 53.00     1
# 55.68     1
# 56.60     1
# ...     ...
# 85.80     1
# 86.50     1
# 87.00     3
# 88.00     1
# 89.40     1
#
# [72 rows x 1 columns]

# %%
sns.histplot(data['ssc_p'],bins = 30)

# %% [markdown]
# 3. ssc_b

# %%
tab3 = pd.crosstab(index = data['ssc_b'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0    Freq  Percentage
# ssc_b
# Central    78   52.702703
# Others     70   47.297297

# %% [markdown]
# 4. hsc_p

# %%
tab4 = pd.crosstab(index = data['hsc_p'],columns = 'Freq')
tab4['Percentage'] = tab4['Freq']/tab4['Freq'].sum()*100
tab4
# Out:
# col_0  Freq  Percentage
# hsc_p
# 50.83     1    0.675676
# 53.00     1    0.675676
# 56.00     2    1.351351
# 57.00     1    0.675676
# 58.00     2    1.351351
# ...     ...         ...
# 90.90     1    0.675676
# 91.00     1    0.675676
# 92.00     1    0.675676
# 97.00     1    0.675676
# 97.70     1    0.675676
#
# [71 rows x 2 columns]

# %%
sns.histplot(data['hsc_p'])

# %% [markdown]
# 5. hsc_b

# %%
tab3 = pd.crosstab(index = data['hsc_b'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0    Freq  Percentage
# hsc_b
# Central    57   38.513514
# Others     91   61.486486

# %% [markdown]
# 6. hsc_s

# %%
tab3 = pd.crosstab(index = data['hsc_s'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0     Freq  Percentage
# hsc_s
# Arts         6    4.054054
# Commerce    79   53.378378
# Science     63   42.567568

# %% [markdown]
# 7. degree_p

# %%
tab3 = pd.crosstab(index = data['degree_p'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0     Freq  Percentage
# degree_p
# 56.00        4    2.702703
# 56.87        1    0.675676
# 57.00        2    1.351351
# 58.00        3    2.027027
# 59.00        2    1.351351
# ...        ...         ...
# 82.00        1    0.675676
# 83.00        1    0.675676
# 84.00        1    0.675676
# 85.00        1    0.675676
# 91.00        1    0.675676
#
# [69 rows x 2 columns]

# %% [markdown]
# 8. degree_t

# %%
tab3 = pd.crosstab(index = data['degree_t'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0      Freq  Percentage
# degree_t
# Comm&Mgmt   102   68.918919
# Others        5    3.378378
# Sci&Tech     41   27.702703

# %% [markdown]
# 9. workexp

# %%
tab3 = pd.crosstab(index = data['workex'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0   Freq  Percentage
# workex
# No        84   56.756757
# Yes       64   43.243243

# %%
sns.countplot(data['workex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 10. status

# %%
tab3 = pd.crosstab(index = data['status'],columns = 'Freq')
tab3['Percentage'] = tab3['Freq']/tab3['Freq'].sum()*100
tab3
# Out:
# col_0   Freq  Percentage
# status
# Placed   148       100.0

# %%
sn
